# %% [markdown]
# # EDA (EXPLORATORY DATA ANALYSIS)

# %%
import pandas as pd

df = pd.read_csv(r"/home/samir-dahal/Downloads/Dataset of Diabetes .csv")
df.head()
# Out:
#     ID  No_Pation Gender  AGE  Urea  Cr  HbA1c  Chol   TG  HDL  LDL  VLDL  \
# 0  502      17975      F   50   4.7  46    4.9   4.2  0.9  2.4  1.4   0.5
# 1  735      34221      M   26   4.5  62    4.9   3.7  1.4  1.1  2.1   0.6
# 2  420      47975      F   50   4.7  46    4.9   4.2  0.9  2.4  1.4   0.5
# 3  680      87656      F   50   4.7  46    4.9   4.2  0.9  2.4  1.4   0.5
# 4  504      34223      M   33   7.1  46    4.9   4.9  1.0  0.8  2.0   0.4
#
#     BMI CLASS
# 0  24.0     N
# 1  23.0     N
# 2  24.0     N
# 3  24.0     N
# 4  21.0     N

# %%
df.tail()
# Out:
#       ID  No_Pation Gender  AGE  Urea  Cr  HbA1c  Chol   TG  HDL  LDL  VLDL  \
# 995  200     454317      M   71  11.0  97    7.0   7.5  1.7  1.2  1.8   0.6
# 996  671     876534      M   31   3.0  60   12.3   4.1  2.2  0.7  2.4  15.4
# 997  669      87654      M   30   7.1  81    6.7   4.1  1.1  1.2  2.4   8.1
# 998   99      24004      M   38   5.8  59    6.7   5.3  2.0  1.6  2.9  14.0
# 999  248      24054      M   54   5.0  67    6.9   3.8  1.7  1.1  3.0   0.7
#
#       BMI CLASS
# 995  30.0     Y
# 996  37.2    Y
# 997  27.4    Y
# 998  40.5    Y
# 999  33.0    Y

# %%
df.shape
# Out:
# (1000, 14)

# %%
df.columns
# Out:
# Index(['ID', 'No_Pation', 'Gender', 'AGE', 'Urea', 'Cr', 'HbA1c', 'Chol', 'TG',
#        'HDL', 'LDL', 'VLDL', 'BMI', 'CLASS'],
#       dtype='object')

# %%
df.dtypes
# Out:
# ID             int64
# No_Pation      int64
# Gender        object
# AGE            int64
# Urea         float64
# Cr             int64
# HbA1c        float64
# Chol         float64
# TG           float64
# HDL          float64
# LDL          float64
# VLDL         float64
# BMI          float64
# CLASS         object
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 14 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   ID         1000 non-null   int64
#  1   No_Pation  1000 non-null   int64
#  2   Gender     1000 non-null   object
#  3   AGE        1000 non-null   int64
#  4   Urea       1000 non-null   float64
#  5   Cr         1000 non-null   int64
#  6   HbA1c      1000 non-null   float64
#  7   Chol       1000 non-null   float64
#  8   TG         1000 non-null   float64
#  9   HDL        1000 non-null   float64
#  10  LDL        1000 non-null   float64
#  11  VLDL       1000 non-null   float64
#  12  BMI        1000 non-null   float64
#  13  CLASS      1000 non-null   object
# dtypes: float64(8), int64(4), object(2)
# memory usage: 109.5+ KB

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df["CLASS"].value_counts()
# Out:
# CLASS
# Y    844
# N    103
# P     53
# Name: count, dtype: int64

# %%
# Remove unwanted whitespace from CLASS values to fix duplicate looking categories
df["CLASS"] = df["CLASS"].str.strip()
df["CLASS"].value_counts()
# Out:
# CLASS
# Y    844
# N    103
# P     53
# Name: count, dtype: int64

# %%
df["ID"].duplicated().sum()
# Out:
# np.int64(200)

# %%
# Get rows where the ID value appears more than once, sort them by ID, and show the first 20 rows
df[df["ID"].duplicated(keep=False)].sort_values("ID").head(20)
# Out:
#      ID  No_Pation Gender  AGE  Urea   Cr  HbA1c  Chol   TG  HDL  LDL  VLDL  \
# 273   1      34325      M   58  20.8  800    9.1   6.6  2.9  1.1  4.3   1.3
# 846   1      34325      M   56  20.8  800    9.0   4.6  2.0  1.2  2.5   0.9
# 847   2      44835      M   60   2.1   56    7.2   6.3  3.7  1.0  3.7   1.7
# 541   2      44835      M   60   2.1   56    7.6   3.3  1.7  0.9  1.7   0.8
# 848   3      41248      M   53   4.2   55    8.0   5.0  2.5  1.3  2.3   1.6
# 301   3      23972      F   56   4.0   45    9.2   4.1  0.6  1.3  1.4   0.9
# 108   4      34301      F   43   2.1   55    5.7   4.7  5.3  0.9  1.7   2.4
# 849   4      18642      M   55   9.2  101    8.5   5.6  1.9  1.3  1.2   0.7
# 487   5      35150      M   63   7.0   84    8.1   6.0  2.2  1.1  4.0   1.0
# 850   5      51477      M   58   5.9   67    9.9   5.2  1.8  0.9  3.6   0.6
# 851   6      45308      F   58   6.0   66    6.9   5.7  1.3  1.4  4.9   0.6
# ...

# %%
df["No_Pation"].duplicated().sum()
# Out:
# np.int64(39)

# %%
df[df["No_Pation"].duplicated(keep=False)].sort_values("No_Pation").head()
# Rows with duplicate patient numbers
# Out:
#       ID  No_Pation Gender  AGE  Urea  Cr  HbA1c  Chol   TG  HDL  LDL  VLDL  \
# 697  576        234      M   66   4.1  63   10.1   3.6  5.1  0.9  2.5   0.9
# 599  584        234      M   59   4.2  56   10.5   4.9  2.1  1.1  2.5   0.9
# 664  554        345      M   55   4.4  56   10.0   4.9  2.1  1.1  2.5   0.9
# 947  122        345      M   60   3.3  59    7.6   3.5  1.0  1.3  1.5   0.7
# 868   28        856      F   55   8.5  59    7.6   3.3  1.7  0.9  1.7   0.8
#
#       BMI CLASS
# 697  30.0     Y
# 599  28.0     Y
# 664  28.0     Y
# 947  30.0     Y
# 868  32.0     Y

# %%
# Remove ID column and duplicate patients (keep first occurrence)
df_clean = df.drop(columns=["ID"]).drop_duplicates(subset="No_Pation", keep="first")
df_clean.shape
# Out:
# (961, 13)

# %%
# Verify no duplicate patients remain
df_clean["No_Pation"].duplicated().sum()
# Out:
# np.int64(0)

# %%
df_clean["CLASS"].value_counts()
# Out:
# CLASS
# Y    810
# N     98
# P     53
# Name: count, dtype: int64

# %%
# Class distribution - percentages
df_clean["CLASS"].value_counts(normalize=True) * 100
# Out:
# CLASS
# Y    84.287201
# N    10.197711
# P     5.515088
# Name: proportion, dtype: float64

# %%
# Visualize class distribution - bar plot
import matplotlib.pyplot as plt

plt.figure(figsize=(8, 5))
df_clean["CLASS"].value_counts().plot(
    kind="bar", color=["#2ecc71", "#e74c3c", "#f39c12"]
)
plt.title("Class Distribution (N, Y, P)", fontsize=14, fontweight="bold")
plt.xlabel("Class", fontsize=12)
plt.ylabel("Count", fontsize=12)
plt.xticks(rotation=0)
plt.tight_layout()
plt.show()

# %%
# Visualize class distribution - pie chart
plt.figure(figsize=(8, 6))
colors = ["#2ecc71", "#e74c3c", "#f39c12"]
df_clean["CLASS"].value_counts().plot(
    kind="pie", autopct="%1.1f%%", colors=colors, startangle=90
)
plt.title("Class Distribution Percentage", fontsize=14, fontweight="bold")
plt.ylabel("")
plt.tight_layout()
plt.show()

# %%
# Check for class imbalance
class_counts = df_clean["CLASS"].value_counts()
imbalance_ratio = class_counts.max() / class_counts.min()
print(f"Imbalance ratio (max/min): {imbalance_ratio:.2f}")
# Out:
# Imbalance ratio (max/min): 15.28

# %%
df_clean.describe()
# Out:
#           No_Pation         AGE        Urea          Cr       HbA1c  \
# count  9.610000e+02  961.000000  961.000000  961.000000  961.000000
# mean   2.723082e+05   53.378772    5.074863   67.734651    8.293236
# std    3.448473e+06    8.701779    2.824144   55.877650    2.531741
# min    1.230000e+02   20.000000    0.500000    6.000000    0.900000
# 25%    2.406100e+04   51.000000    3.660000   48.000000    6.500000
# 50%    3.438500e+04   55.000000    4.600000   60.000000    8.000000
# 75%    4.537100e+04   59.000000    5.700000   73.000000   10.200000
# max    7.543566e+07   79.000000   38.900000  800.000000   16.000000
#
#              Chol          TG         HDL         LDL        VLDL         BMI
# count  961.000000  961.000000  961.000000  961.000000  961.000000  961.000000
# mean     4.865369    2.331436    1.208481    2.612581    1.872216   29.594089
# std      1.296793    1.401131    0.671537    1.122127    3.728367    4.998684
# ...

# %%
# Select only numerical features for analysis
numerical_cols = df_clean.select_dtypes(include=["number"]).columns.tolist()
numerical_cols.remove("No_Pation")  # Remove patient ID
print(f"Numerical features: {numerical_cols}")
# Out:
# Numerical features: ['AGE', 'Urea', 'Cr', 'HbA1c', 'Chol', 'TG', 'HDL', 'LDL', 'VLDL', 'BMI']

# %%
# Distribution plots for all numerical features
fig, axes = plt.subplots(4, 3, figsize=(15, 12))
axes = axes.ravel()

for idx, col in enumerate(numerical_cols):
    df_clean[col].hist(bins=30, ax=axes[idx], edgecolor="black", alpha=0.7)
    axes[idx].set_title(f"{col} Distribution", fontweight="bold")
    axes[idx].set_xlabel(col)
    axes[idx].set_ylabel("Frequency")

plt.tight_layout()
plt.show()

# %%
# Box plots to detect outliers
fig, axes = plt.subplots(4, 3, figsize=(15, 12))
axes = axes.ravel()

for idx, col in enumerate(numerical_cols):
    df_clean.boxplot(column=col, ax=axes[idx])
    axes[idx].set_title(f"{col} Boxplot", fontweight="bold")
    axes[idx].set_ylabel(col)

plt.tight_layout()
plt.show()

# %%
# Count outliers using IQR method for each feature
for col in numerical_cols:
    Q1 = df_clean[col].quantile(0.25)
    Q3 = df_clean[col].quantile(0.75)
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR
    outliers = df_clean[(df_clean[col] < lower_bound) | (df_clean[col] > upper_bound)]
    print(
        f"{col}: {len(outliers)} outliers ({len(outliers) / len(df_clean) * 100:.1f}%)"
    )
# Out:
# AGE: 92 outliers (9.6%)
# Urea: 58 outliers (6.0%)
# Cr: 46 outliers (4.8%)
# HbA1c: 4 outliers (0.4%)
# Chol: 24 outliers (2.5%)
# TG: 52 outliers (5.4%)
# HDL: 50 outliers (5.2%)
# LDL: 11 outliers (1.1%)
# VLDL: 72 outliers (7.5%)
# BMI: 3 outliers (0.3%)

# %%
# Gender distribution
df_clean["Gender"].value_counts()
# Out:
# Gender
# M    541
# F    419
# f      1
# Name: count, dtype: int64

# %%
df_clean["Gender"] = df_clean["Gender"].str.upper()
df_clean["Gender"].value_counts()
# Out:
# Gender
# M    541
# F    420
# Name: count, dtype: int64

# %%
# Gender vs CLASS crosstab
pd.crosstab(df_clean["Gender"], df_clean["CLASS"], margins=True)
# Out:
# CLASS    N   P    Y  All
# Gender
# F       61  17  342  420
# M       37  36  468  541
# All     98  53  810  961

# %%
# Correlation matrix
import seaborn as sns
correlation_matrix = df_clean[numerical_cols].corr()

plt.figure(figsize=(12, 10))
sns.heatmap(
    correlation_matrix,
    annot=True,
    fmt=".2f",
    cmap="coolwarm",
    center=0,
    square=True,
    linewidths=1,
    cbar_kws={"shrink": 0.8},
)
plt.title("Correlation Matrix of Numerical Features", fontsize=16, fontweight="bold")
plt.tight_layout()
plt.show()

# %%
# Features vs CLASS - violin plots for key features
key_features = ["HbA1c", "BMI", "AGE", "Chol"]

fig, axes = plt.subplots(2, 2, figsize=(14, 10))
axes = axes.ravel()

for idx, col in enumerate(key_features):
    sns.violinplot(
        data=df_clean,
        x="CLASS",
        y=col,
        hue="CLASS",             # add hue to avoid warning
        legend=False,            # remove legend
        ax=axes[idx],
        palette=["#2ecc71", "#f39c12", "#e74c3c"],
    )
    axes[idx].set_title(f"{col} by CLASS", fontweight="bold", fontsize=12)
    axes[idx].set_xlabel("CLASS")
    axes[idx].set_ylabel(col)

plt.tight_layout()
plt.show()

# %%
# Check which features might have unusual distributions
for col in numerical_cols:
    unique_count = df_clean[col].nunique()
    print(
        f"{col}: {unique_count} unique values, min={df_clean[col].min()}, max={df_clean[col].max()}"
    )
# Out:
# AGE: 50 unique values, min=20, max=79
# Urea: 109 unique values, min=0.5, max=38.9
# Cr: 112 unique values, min=6, max=800
# HbA1c: 109 unique values, min=0.9, max=16.0
# Chol: 75 unique values, min=0.5, max=10.3
# TG: 68 unique values, min=0.3, max=13.8
# HDL: 48 unique values, min=0.2, max=9.9
# LDL: 65 unique values, min=0.3, max=9.9
# VLDL: 60 unique values, min=0.1, max=35.0
# BMI: 63 unique values, min=19.0, max=47.75

# %%
# Investigate extreme Cr values
extreme_cr = df_clean[df_clean["Cr"] > 100]
print(f"Patients with Cr > 100: {len(extreme_cr)}")
extreme_cr[["AGE", "Cr", "Urea", "HbA1c", "CLASS"]].sort_values(
    "Cr", ascending=False
).head(10)
# Out:
# Patients with Cr > 100: 55
#      AGE   Cr  Urea  HbA1c CLASS
# 273   58  800  20.8    9.1     Y
# 283   58  800  20.8    9.1     Y
# 860   60  800  20.8    9.0     Y
# 590   55  401  24.0    6.3     Y
# 592   61  401  24.0    7.0     Y
# 589   61  401  24.0    7.0     Y
# 208   57  370   4.6    6.8     Y
# 212   57  370   4.6    6.8     Y
# 151   30  344  17.1    6.0     P
# 807   53  327  14.9   11.0     Y

# %%
# Investigate very low cholesterol values
low_chol = df_clean[df_clean["Chol"] < 2]
print(f"Patients with Chol < 2: {len(low_chol)}")
low_chol[["AGE", "Chol", "HDL", "LDL", "VLDL", "CLASS"]].head(10)
# Out:
# Patients with Chol < 2: 4
#      AGE  Chol  HDL  LDL  VLDL CLASS
# 20    49   0.5  1.3  2.8   0.8     N
# 342   58   0.6  1.1  2.0   0.6     Y
# 345   58   0.6  1.1  2.0   0.6     Y
# 724   54   1.2  1.0  0.5   1.5     Y
